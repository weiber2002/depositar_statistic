# %%
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
# !pip install wikidataintegrator
# !pip install pytz
# !pip install ckanapi
# !apt-get install gzip
# !pip install matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import subprocess
import gzip
import json
import requests
from matplotlib.font_manager import fontManager
from collections import Counter
from matplotlib import pyplot as plt
# import warnings
# warnings.filterwarnings("ignore")

# !pip install jupyterlab-language-pack-zh-TW
# plt.rcParams["font.family"] = "Taipei Sans TC Beta"
# plt.rcParams["font.sans-serif"] = ['~/project']
fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# Requirement already satisfied: wikidataintegrator in /home/weipo/project/lib/python3.10/site-packages (0.9.30)
# Requirement already satisfied: backoff in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (2.2.1)
# Requirement already satisfied: mwoauth in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (0.3.8)
# Requirement already satisfied: simplejson in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (3.19.1)
# Requirement already satisfied: shexer in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (2.2.0)
# Requirement already satisfied: requests in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (2.31.0)
# Requirement already satisfied: python-dateutil in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (2.8.2)
# Requirement already satisfied: jsonasobj in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (1.3.1)
# Requirement already satisfied: pandas in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (2.0.3)
# Requirement already satisfied: oauthlib in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (3.2.2)
# Requirement already satisfied: pyshex in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (0.8.1)
# Requirement already satisfied: tqdm in /home/weipo/project/lib/python3.10/site-packages (from wikidataintegrator) (4.65.0)
# Requirement already satisfied: PyJWT>=1.0.1 in /home/weipo/project/lib/python3.10/site-packages (from mwoauth->wikidataintegrator) (2.8.0)
# Requirement already satisfied: requests-oauthlib in /home/weipo/project/lib/python3.10/site-packages (from mwoauth->wikidataintegrator) (1.3.1)
# Requirement already satisfied: six in /home/weipo/project/lib/python3.10/site-packages (from mwoauth->wikidataintegrator) (1.16.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/weipo/project/lib/python3.10/site-packages (from pandas->wikidataintegrator) (1.25.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/weipo/project/lib/python3.10/site-packages (from pandas->wikidataintegrator) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/weipo/project/lib/python3.10/site-packages (from pandas->wikidataintegrator) (2023.3)
# Requirement already satisfied: pyshexc==0.9.1 in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (0.9.1)
# Requirement already satisfied: rdflib-shim in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (1.0.3)
# Requirement already satisfied: urllib3 in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (2.0.4)
# Requirement already satisfied: cfgraph>=0.2.1 in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (0.2.1)
# Requirement already satisfied: sparqlwrapper>=1.8.5 in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (2.0.0)
# Requirement already satisfied: chardet in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (5.2.0)
# Requirement already satisfied: shexjsg>=0.8.2 in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (0.8.2)
# Requirement already satisfied: sparqlslurper>=0.5.1 in /home/weipo/project/lib/python3.10/site-packages (from pyshex->wikidataintegrator) (0.5.1)
# Requirement already satisfied: antlr4-python3-runtime~=4.9.3 in /home/weipo/project/lib/python3.10/site-packages (from pyshexc==0.9.1->pyshex->wikidataintegrator) (4.9.3)
# Requirement already satisfied: pyjsg>=0.11.10 in /home/weipo/project/lib/python3.10/site-packages (from pyshexc==0.9.1->pyshex->wikidataintegrator) (0.11.10)
# Requirement already satisfied: idna<4,>=2.5 in /home/weipo/project/lib/python3.10/site-packages (from requests->wikidataintegrator) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/weipo/project/lib/python3.10/site-packages (from requests->wikidataintegrator) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/weipo/project/lib/python3.10/site-packages (from requests->wikidataintegrator) (2023.7.22)
# Requirement already satisfied: Flask in /home/weipo/project/lib/python3.10/site-packages (from shexer->wikidataintegrator) (2.3.2)
# Requirement already satisfied: Flask-Cors in /home/weipo/project/lib/python3.10/site-packages (from shexer->wikidataintegrator) (4.0.0)
# Requirement already satisfied: rdflib in /home/weipo/project/lib/python3.10/site-packages (from shexer->wikidataintegrator) (7.0.0)
# Requirement already satisfied: rdflib-jsonld in /home/weipo/project/lib/python3.10/site-packages (from shexer->wikidataintegrator) (0.6.1)
# Requirement already satisfied: wlighter in /home/weipo/project/lib/python3.10/site-packages (from shexer->wikidataintegrator) (1.0.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /home/weipo/project/lib/python3.10/site-packages (from rdflib->shexer->wikidataintegrator) (3.0.9)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /home/weipo/project/lib/python3.10/site-packages (from rdflib->shexer->wikidataintegrator) (0.6.1)
# Requirement already satisfied: Werkzeug>=2.3.3 in /home/weipo/project/lib/python3.10/site-packages (from Flask->shexer->wikidataintegrator) (2.3.6)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/weipo/project/lib/python3.10/site-packages (from Flask->shexer->wikidataintegrator) (3.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /home/weipo/project/lib/python3.10/site-packages (from Flask->shexer->wikidataintegrator) (1.6.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/weipo/project/lib/python3.10/site-packages (from Flask->shexer->wikidataintegrator) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /home/weipo/project/lib/python3.10/site-packages (from Flask->shexer->wikidataintegrator) (8.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/weipo/project/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask->shexer->wikidataintegrator) (2.1.3)
# Requirement already satisfied: pytz in /home/weipo/project/lib/python3.10/site-packages (2023.3)
# Requirement already satisfied: ckanapi in /home/weipo/project/lib/python3.10/site-packages (4.7)
# Requirement already satisfied: docopt in /home/weipo/project/lib/python3.10/site-packages (from ckanapi) (0.6.2)
# Requirement already satisfied: python-slugify>=1.0 in /home/weipo/project/lib/python3.10/site-packages (from ckanapi) (8.0.1)
# Requirement already satisfied: requests in /home/weipo/project/lib/python3.10/site-packages (from ckanapi) (2.31.0)
# Requirement already satisfied: setuptools in /home/weipo/project/lib/python3.10/site-packages (from ckanapi) (59.6.0)
# Requirement already satisfied: six<2.0,>=1.9 in /home/weipo/project/lib/python3.10/site-packages (from ckanapi) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /home/weipo/project/lib/python3.10/site-packages (from python-slugify>=1.0->ckanapi) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/weipo/project/lib/python3.10/site-packages (from requests->ckanapi) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/weipo/project/lib/python3.10/site-packages (from requests->ckanapi) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /home/weipo/project/lib/python3.10/site-packages (from requests->ckanapi) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/weipo/project/lib/python3.10/site-packages (from requests->ckanapi) (2.0.4)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# Requirement already satisfied: matplotlib in /home/weipo/project/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: cycler>=0.10 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: numpy>=1.20 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/weipo/project/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/weipo/project/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 22
#      15 from matplotlib import pyplot as plt
#      16 # import warnings
#      17 # warnings.filterwarnings("ignore")
#      18
#      19
#      20 # plt.rcParams["font.family"] = "Taipei Sans TC Beta"
#      21 # plt.rcParams["font.sans-serif"] = ['~/project']
# ---> 22 fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
#      23 mpl.rc('font', family='Taipei Sans TC Beta')
#
# File ~/project/lib/python3.10/site-packages/matplotlib/font_manager.py:1044, in FontManager.addfont(self, path)
#    1042     self.afmlist.append(prop)
#    1043 else:
# -> 1044     font = ft2font.FT2Font(path)
#    1045     prop = ttfFontProperty(font)
#    1046     self.ttflist.append(prop)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TaipeiSansTCBeta-Regular.ttf'

# %%
# Set the command

cmd = [  # for package
    'ckanapi',
    'search',
    'datasets',
    '-O',
    'datasets.jsonl.gz',
    '-z',
    '-r',
    'https://data.depositar.io'
]

# Execute the command
subprocess.run(cmd, check=True)

o_dataset = []


with gzip.open("datasets.jsonl.gz", "rb") as f_in:
    with open("datasets.jsonl", "wb") as f_out:
        f_out.write(f_in.read())
with open("datasets.jsonl", "r") as f: #游標位置會變
    line_count = 0
    for line in f:
      line_count += 1
    f.seek(0) #讓游標讀取位置回到原點
    for i in range(line_count):
        line = f.readline()
        data = json.loads(line)
        o_dataset.append(data)
print(o_dataset[:2])
# Out:
# /home/weipo/project/lib/python3.10/site-packages/ckanapi/cli/search.py:63: FutureWarning: GzipFile was opened for writing, but this will change in future Python releases.  Specify the mode argument for opening it for writing.
#   jsonl_output = gzip.GzipFile(fileobj=jsonl_output)
# [{'author': '逢甲大學水利發展中心', 'author_email': None, 'contact_email': '', 'contact_person': '', 'creator_user_id': 'dbf82753-0564-4ca2-a855-fa81cb5615d1', 'data_type': ['archive', 'database', 'doc', 'image', 'science', 'other'], 'groups': [], 'id': '6fb6dd5c-5886-4d2b-8d73-c8f2eacfc851', 'isopen': False, 'keywords': [], 'language': [], 'license_id': 'notspecified', 'license_title': 'License Not Specified', 'maintainer': None, 'maintainer_email': None, 'metadata_created': '2022-04-08T04:01:52.105456', 'metadata_modified': '2023-08-07T01:29:52.403488', 'name': '1-2-4', 'notes': '本報告主要針對現況環境屬人為使用干擾強度較大的平面道路工區1、堤防道路、平面道路工區2與平面道路工區4等四個工區，以及跨河段的橋樑工區1，進行施工前補充之生態檢核作業辦理。\r\n於開工後持續辦理各月份之施工階段生態檢核作業。', 'num_resources': 44, 'num_tags': 0, 'organization': {'approval_status': 'approved', 'created': '2022-04-08T18:00:27.813532', 'description': '', 'id': '70eca0ce-5714-4441-9c35-6ca802c31830', 'image_url': '2022-12-08-062841.682649.PNG', 'is_organization': True, 'name': '1594321316456', 'state': 'active', 'title': '溫寮溪旁(甲后路至經國路)聯絡道路新闢工程 ', 'type': 'organization'}, 'owner_org': '70eca0ce-5714-4441-9c35-6ca802c31830', 'private': False, 'process_step': '', 'relationships_as_object': [], 'relationships_as_subject': [], 'remarks': '', 'resources': [{'cache_last_updated': None, 'cache_url': None, 'created': '2022-04-08T04:04:05.495575', 'datastore_active': False, 'datastore_contains_all_records_of_source_file': False, 'description': '民國111年 2 月底～3 月初溫寮溪道路工程全工區之生態調查結果\r\n盤點中查詢心點坐標：(X:212700 Y:2692500)(97 坐標)\r\n查詢範圍：半徑 2 公里\r\n', 'format': 'PDF', 'hash': '', 'id': 'e9a82645-dcc2-4de8-a83a-f1bad87c40f6', 'last_modified': '2022-12-27T10:23:09.633059', 'metadata_modified': '2023-01-05T08:26:58.209680', 'mimetype': 'application/pdf', 'mimetype_inner': None, 'name': '111年 2 月底～3 月初之生態調查結果', 'package_id': '6fb6dd5c-5886-4d2b-8d73-c8f2eacfc851', 'position': 0, 'resource_crs': 4326, 'resource_type': None, 'size': 1944522, 'state': 'active', 'url': 'https://data.depositar.io/dataset/6fb6dd5c-5886-4d2b-8d73-c8f2eacfc851/resource/e9a82645-dcc2-4de8-a83a-f1bad87c40f6/download/01-%2525252525252525252525252525252525252525252525252525252525252525252525252525252525252525252525.pdf', 'url_type': 'upload'}, {'cache_last_updated': None, 'cache_url': None, 'created': '2022-04-08T04:05:27.938190', 'datastore_active': False, 'datastore_contains_all_records_of_source_file': False, 'description': '本次工程5工區(平面道路工區1、堤防道路、橋樑工區1、平面道路工區2、平面道路工區4)辦理之施工前補充生態檢核成果。\r\n工區座標:WGS84\r\n平面道路工區1-(24.34153, 120.61840)\r\n堤防道路-(24.34024, 120.62166)\r\n橋樑工區1-(24.33870, 120.62482)\r\n平面道路工區2-(24.33742, 120.62803)\r\n平面道路工區4-(24.33763, 120.64401)', 'format': 'PDF', 'hash': '', 'id': '122aaca8-fd98-4060-8664-a983f8d39f09', 'last_modified': '2022-04-08T09:15:46.896787', 'metadata_modified': '2023-01-05T07:23:17.079742', 'mimetype': 'application/pdf', 'mimetype_inner': None, 'name': '本次工程5工區施工前補充生態檢核成果', 'package_id': '6fb6dd5c-5886-4d2b-8d73-c8f2eacfc851', 'position': 1, 'resource_crs': 4326, 'resource_type': None, 'size': 4029948, 'state': 'active', 'url': 'https://data.depositar.io/dataset/6fb6dd5c-5886-4d2b-8d73-c8f2eacfc851/resource/122aaca8-fd98-4060-8664-a983f8d39f09/download/02-%2525252525252525252525252525252525252525252525252525252525252525252525252525252525252525252525.pdf', 'url_type': 'upload'}, {'cache_last_updated': None, 'cache_url': None, 'created': '2022-04-08T04:05:51.390027', 'datastore_active': False, 'datastore_contains_all_records_of_source_file': False, 'description': '既有喬木初步健檢結果\r\n中心點坐標：(X:212700 Y:2692500)(97 坐標) ', 'format': 'PDF', 'hash': '', 'id': '9c2123b4-8053-4c09-8aaa-12b02ef1dff7', 'last_modified': '2022-04-08T04:05:51.310004', 'metadata_modified': '2023-01-05T07:58:41.669817', 'mimetype': 'application/pdf', 'mimetype_inner': None, 'name': '既有喬木初步健檢結果', 'package_id': '6fb6dd5c-5886-4d2b-8d73-c8f2eacfc851', 'position': 2, 'resource_type': None, 'size': 19881930, 'state': 'active', 'url': 'https://data.depositar.io/dataset/6fb6dd5c-5886-4d2b-8d73-c8f2eacfc851/resource/9 ...

# %%
cmd = [  # for package
    'ckanapi',
    'dump',
    'organizations',
    '--all',
    '-O',
    'projects.jsonl.gz',
    '-z',
    '-r',
    'https://data.depositar.io'
]

subprocess.run(cmd, check=True)

o_project = []

with gzip.open("projects.jsonl.gz", "rb") as f_in:
    with open("projects.jsonl", "wb") as f_out:
        f_out.write(f_in.read())
with open("projects.jsonl", "r") as f: #游標位置會變
    line_count = 0
    for line in f:
      line_count += 1
    f.seek(0) #讓游標讀取位置回到原點
    for i in range(line_count):
        line = f.readline()
        data = json.loads(line)
        o_project.append(data)
# Out:
# /home/weipo/project/lib/python3.10/site-packages/ckanapi/cli/dump.py:49: FutureWarning: GzipFile was opened for writing, but this will change in future Python releases.  Specify the mode argument for opening it for writing.
#   jsonl_output = gzip.GzipFile(fileobj=jsonl_output)
# 0 [1] --- None 107ecological_check_project_of_keelung_city_2018
# 1 [2] 0.05s None ecocheck_taichung_2018
# 2 [3] 0.05s None ecological-considerations-107yilan
# 3 [4] 0.05s None chiahung
# 4 [5] 0.05s None ecological-considerations-107hsinchu
# 5 [6] 0.05s None 107-taoyuan
# 6 [7] 0.05s None 107
# 7 [8] 0.06s None ecological-considerations-107miaoli
# 8 [9] 0.05s None 2018
# 9 [10] 0.05s None 107yl
# 10 [11] 0.06s None ecological-considerations-107kaohsiung
# 11 [12] 0.05s None bn-right3
# 12 [13] 0.05s None ecocheck_taichung_2019-2020
# 13 [14] 0.05s None cycwater108109
# 14 [15] 0.04s None 108109changhuacology
# 15 [16] 0.04s None 109ch
# 16 [17] 0.05s None ch108-109
# 17 [18] 0.05s None 108-109_hsinchu
# 18 [19] 0.04s None ecocheck_miaoli_2019-2020
# 19 [20] 0.04s None yunlin_ecocheck_108-109
# 20 [21] 0.05s None yunlin_ecocheck_108-109_110
# 21 [22] 0.05s None 108
# 22 [23] 0.05s None 108taichung
# 23 [24] 0.04s None 109-_-_
# 24 [25] 0.04s None 109taipei
# 25 [26] 0.04s None 109-_
# 26 [27] 0.04s None 10911
# 27 [28] 0.06s None 110-111changhua
# 28 [29] 0.05s None 110-111newtaipei
# 29 [30] 0.04s None w110009
# 30 [31] 0.05s None bnright1
# 31 [32] 0.05s None yongle2k470
# 32 [33] 0.05s None tt-right1
# 33 [34] 0.05s None yunlin_ecocheck_110-111
# 34 [35] 0.05s None 110-111kaohsiung-ecologicalinspection
# 35 [36] 0.05s None wra5-110-bz
# 36 [37] 0.04s None 1101
# 37 [38] 0.05s None 110
# 38 [39] 0.04s None taoenvegoven
# 39 [40] 0.22s None 110wra06
# 40 [41] 0.06s None 110c8763
# 41 [42] 0.04s None 112-113changhua
# 42 [43] 0.05s None 112-113newtaipei
# 43 [44] 0.05s None yunlin_ecocheck_112-113
# 44 [45] 0.05s None 119-26k-000-26k-670
# 45 [46] 0.05s None 123
# 46 [47] 0.04s None 128-3k-600-4k-900
# 47 [48] 0.06s None nantouecologicalguardian1995_2040
# 48 [49] 0.05s None 2008-paworkshop
# 49 [50] 0.05s None 2009-playaround-workshop
# 50 [51] 0.05s None 2010-playaround-workshop
# 51 [52] 0.05s None 2012-playaround-workshop
# 52 [53] 0.05s None 2018-playaround-workshop
# 53 [54] 0.05s None 2020_2050nantouanalyze
# 54 [55] 0.05s None 2021geomatics
# 55 [56] 0.05s None landscape-doc-2021
# 56 [57] 0.05s None 2022iis-intern-depositar
# 57 [58] 0.05s None 2022-summer-gravesite-survey
# 58 [59] 0.05s None ml-rcdec-2022
# 59 [60] 0.05s None 2023-_-narration-exploration-and-presentation-of-wikidata-annotated-resources
# 60 [61] 0.05s None 2023-summer-projects
# 61 [62] 0.17s None 38
# 62 [63] 0.05s None fair
# 63 [64] 0.05s None nanshan_2021-10-14
# 64 [65] 0.05s None ai-cup
# 65 [66] 0.06s None angis
# 66 [67] 0.05s None asian-eco-net
# 67 [68] 0.05s None asian-forest-soundscape
# 68 [69] 0.05s None covid19
# 69 [70] 0.05s None covid19tw
# 70 [71] 0.05s None covid2019
# 71 [72] 0.05s None cities_gi
# 72 [73] 0.04s None clidi
# 73 [74] 0.05s None data-depositar-io-dataset-631e4
# 74 [75] 0.05s None depositar
# 75 [76] 0.05s None ecai-pacific-language-mapping
# 76 [77] 0.05s None fantasybaseball
# 77 [78] 0.05s None geep-ap
# 78 [79] 0.05s None gis_topics
# 79 [80] 0.05s None www-rdr
# 80 [81] 0.06s None gloria-taiwan
# 81 [82] 0.05s None human-paleodiets
# 82 [83] 0.05s None iislab317
# 83 [84] 0.05s None jijiji
# 84 [85] 0.05s None lod-taichung
# 85 [86] 0.05s None low-impact-development-for-sustainable-tourism
# 86 [87] 0.05s None ltserchanghua
# 87 [88] 0.05s None ltser-lyudao
# 88 [89] 0.05s None ltser-feitsuei
# 89 [90] 0.05s None maps-re-imagined
# 90 [91] 0.05s None oceanbiodiversity
# 91 [92] 0.05s None low-cost-sensor
# 92 [93] 0.05s None roger
# 93 [94] 0.05s None study-on-covid-19-vaccination-strategies
# 94 [95] 0.05s None taismart
# 95 [96] 0.07s None tbn
# 96 [97] 0.06s None wbgt
# 97 [98] 0.05s None testpermission
# 98 [99] 0.05s None thakbong
# 99 [100] 0.05s None ultrasoundscape-brcas
# 100 [101] 0.14s None nanshan_2022-03-13
# 101 [102] 0.05s None wikidata-religions-temples-in-tainan-and-penghu
# 102 [103] 0.05s None wildstreamob
# 103 [104] 0.05s None 110_three
# 104 [105] 0.06s None 17-0k-800-1k-150
# 105 [106] 0.06s None irc-pccu
# 106 [107] 0.05s None swchina
# 107 [108] 0.05s None 22-26-14k-000_16k-406
# 108 [109] 0.06s None as-rchss-gis
# 109 [110] 0.06s None nbs_bstp
# 110 [111] 0.05s None nbis_shezidao
# 111 [112] 0.06s None nbs_taipei-guizikeng
# 112 [113] 0.05s None bps
# 113 [114] 0.06s None 108109
# 114 [115] 0.06s None dataset
# 115 [116] 0.06s None hsinchu112-113
# 116 [117] 0.06s None https-sites-google-com-view-waterenv-hsinchu110-111-e9-a6-96-e9-a0-81
# 117 [118] 0.05s None miaoliwaterproject
# 118 [119] 0.05s None ml_eco-plan
# 119 [120] 0.05s None 110-111-kaohsiung
# 120 [121] 0.05s None lcs_pm_taiwan_indonesia
# 121 [122] 0.05s None bstp-development
# 122 [123] 0.05s None beigang-stream
# 123 [124] 0.05s None beigang_river
# 124 [125] 0.05s None taitung2
# 125 [126] 0.05s None 109-110
# 126 [127] 0.05s None discovering-of-taiwan-historical-maps
# 127 [128] 0.05s None binjijijh-l
# 128 [129] 0.05s None https-www-ud-taichung-gov-tw
# 129 [130] 0.05s None taijiangproject
# 130 [131] 0.05s None taijiang_sustainable_plan
# 131 [132] 0.05s None nsysu
# 132 [133] 0.05s None twrw-eco2021
# 133 [134] 0.05s None he-she-river
# 134 [135] 0.05s None 111
# 135 [136] 0.06s None chia-nan-project
# 136 [137] 0.07s None 10-3
# 137 [138] 0.06s None east-stone
# 138 [139] 0.05s None 107wpro
# 139 [140] 0.05s None 108-109_chiayi
# 140 [141] 0.06s None chiayi110-111
# 141 [142] 0.06s None wmts
# 142 [143] 0.06s None ncyu_invasive_species
# 143 [144] 0.05s None ncyu_safety_map
# 144 [145] 0.05s None ncyu_water_resources
# 145 [146] 0.06s None ncyu_facilities
# 146 [147] 0.05s None ncyu-energy
# 147 [148] 0.05s None ncyu_recycling
# 148 [149] 0.06s None keelung-nuan
# 149 [150] 0.07s None ecological_check_project_of_keelung_city_2019
# 150 [151] 0.06s None 109
# 151 [152] 0.06s None keelung-110
# 152 [153] 0.06s None keelung111
# 153 [154] 0.05s None dazhi_drainage_1
# 154 [155] 0.06s None 12
# 155 [156] 0.06s None 108-dahu
# 156 [157] 0.05s None dagouxi_riverside_park_and_jinruei_riverside_park
# 157 [158] 0.05s None urbanforest
# 158 [159] 0.05s None resilience_uf
# 159 [160] 0.05s None nstc_uttsr_sp2
# 160 [161] 0.05s None 0k-866-1k-547
# 161 [162] 0.06s None annongriver
# 162 [163] 0.05s None zhuangdong
# 163 [164] 0.06s None 108-109yilan
# 164 [165] 0.06s None ecological-considerations-108109yilan
# 165 [166] 0.06s None thcdc
# 166 [167] 0.06s None site2
# 167 [168] 0.05s None liudui
# 168 [169] 0.06s None ky-and-gl
# 169 [170] 0.05s None 10714
# 170 [171] 0.08s None ecological-considerations-108109pingtung
# 171 [172] 0.05s None 110-1111111111111
# 172 [173] 0.05s None xihu-xizhoubicyclelane
# 173 [174] 0.05s None collaborative-badlands-project
# 174 [175] 0.05s None 106_kaohsiung_18
# 175 [176] 0.04s None twedcschildren
# 176 [177] 0.05s None ncku_mtms
# 177 [178] 0.05s None lakulaku_river_basin
# 178 [179] 0.05s None penguin
# 179 [180] 0.12s None ecosystemservice
# 180 [181] 0.05s None _carbon_2020_2023
# 181 [182] 0.06s None 29-5k-14k
# 182 [183] 0.04s None ntwyg4
# 183 [184] 0.04s None hcc_tcr_ecomap_2020
# 184 [185] 0.04s None ecological-considerations-107hsinchu-city
# 185 [186] 0.04s None ecological-considerations-108109hsinchu-city
# 186 [187] 0.05s None 1100-1111
# 187 [188] 0.05s None 112-113
# 188 [189] 0.05s None https-data-depositar-io-dataset-7eb94
# 189 [190] 0.05s None michelle891023
# 190 [191] 0.05s None 10-2
# 191 [192] 0.05s None wiselabproject
# 192 [193] 0.05s None n111230310004
# 193 [194] 0.04s None 751
# 194 [195] 0.05s None oceanbiodiversity-ch
# 195 [196] 0.05s None sandbox
# 196 [197] 0.05s None hahahahatest1
# 197 [198] 0.05s None minshiang
# 198 [199] 0.06s None 1594321316456
# 199 [200] 0.05s None jhuoshuei-river01
# 200 [201] 0.16s None 1-2
# 201 [202] 0.05s None wanli_temple_prescription
# 202 [203] 0.05s None yunlin_ntou5047
# 203 [204] 0.05s None m2010
# 204 [205] 0.05s None contemporary-archiving-in-taiwan
# 205 [206] 0.06s None ecological_check_changhua_shipai
# 206 [207] 0.05s None sssd1
# 207 [208] 0.06s None snsddm2
# 208 [209] 0.04s None snjgdm
# 209 [210] 0.06s None rdm-basics
# 210 [211] 0.05s None xiuguluan-river
# 211 [212] 0.06s None weec
# 212 [213] 0.05s None wra04
# 213 [214] 0.04s None incomplete_datasets
# 214 [215] 0.05s None 166-162
# 215 [216] 0.05s None 169-159
# 216 [217] 0.05s None ege3t1
# 217 [218] 0.05s None 110-111
# 218 [219] 0.05s None 110-1111
# 219 [220] 0.06s None tcgwrbec112-113
# 220 [221] 0.26s None tc_faziriver_landscape-environment-construction-project_107
# 221 [222] 0.05s None tainancp
# 222 [223] 0.05s None panasia-yongkang
# 223 [224] 0.05s None right3
# 224 [225] 0.05s None taitung
# 225 [226] 0.06s None 6ten
# 226 [227] 0.06s None green-heat_inequality
# 227 [228] 0.05s None tccip
# 228 [229] 0.05s None ast
# 229 [230] 0.06s None hualieneconet
# 230 [231] 0.05s None 30
# 231 [232] 0.19s None 107env
# 232 [233] 0.06s None mlsy-ytr-2021
# 233 [234] 0.05s None 128
# 234 [235] 0.05s None ml_eco-monitoring
# 235 [236] 0.05s None green-flow
# 236 [237] 0.06s None miaoliecological112-113
# 237 [238] 0.05s None https-data-depositar-io-dataset-631e4
# 238 [239] 0.06s None lhc_ecosystem_services
# 239 [240] 0.07s None air_faq2017
# 240 [241] 0.07s None gcaa-thaubing-footprint
# 241 [242] 0.05s None miaoli108
# 242 [243] 0.05s None trait
# 243 [244] 0.06s None urban
# 244 [245] 0.06s None sustainability_dmp
# 245 [246] 0.05s None workshop
# 246 [247] 0.05s None tsungchenlee_team
# 247 [248] 0.05s None green-infrastructure_urban-sustainability-transition
# 248 [249] 0.06s None disaster_recovery
# 249 [250] 0.29s None kinmenlibrary
# 250 [251] 0.06s None kinmenjincheng3stage
# 251 [252] 0.36s None data-management-and-publish-in-long-term-socio-ecological-research-ltser
# 252 [253] 0.06s None ltc_energency_pred
# 253 [254] 0.05s None openrdds
# 254 [255] 0.06s None cz-109-2621-m-006-010
# 255 [256] 0.05s None ecoyangmingshan
# 256 [257] 0.05s None 62-1
# 257 [258] 0.06s None yun65_0k-300-1k-860
# 258 [259] 0.05s None 2019sas2th
# 259 [260] 0.06s None touqian-river
# 260 [261] 0.06s None kaohsiung
# 261 [262] 0.06s None _0013
# 262 [263] 0.06s None 108-109
# 263 [264] 0.06s None the-shuang-xi-river-meinong
# 264 [None] 0.06s None tioceansounscape

# %%
# Set the command

cmd = [  # for package
    'ckanapi',
    'dump',
    'groups',
    '--all',
    '-O',
    'topics.jsonl.gz',
    '-z',
    '-r',
    'https://data.depositar.io'
]
# Execute the command
subprocess.run(cmd, check=True)

o_topic = []


with gzip.open("topics.jsonl.gz", "rb") as f_in:
    with open("topics.jsonl", "wb") as f_out:
        f_out.write(f_in.read())
with open("topics.jsonl", "r") as f: #游標位置會變
    line_count = 0
    for line in f:
      line_count += 1
    f.seek(0) #讓游標讀取位置回到原點
    for i in range(line_count):
        line = f.readline()
        data = json.loads(line)
        o_topic.append(data)
# Out:
# /home/weipo/project/lib/python3.10/site-packages/ckanapi/cli/dump.py:49: FutureWarning: GzipFile was opened for writing, but this will change in future Python releases.  Specify the mode argument for opening it for writing.
#   jsonl_output = gzip.GzipFile(fileobj=jsonl_output)
# 0 [1] --- None general-reference
# 1 [2] 0.07s None culture-and-the-arts
# 2 [3] 0.07s None geography-and-places
# 3 [4] 0.07s None health-and-fitness
# 4 [5] 0.07s None history-and-events
# 5 [6] 0.07s None human-activities
# 6 [7] 0.07s None mathematics-and-logic
# 7 [8] 0.06s None natural-and-physical-sciences
# 8 [9] 0.07s None people-and-self
# 9 [10] 0.07s None philosophy-and-thinking
# 10 [11] 0.06s None 110picture
# 11 [12] 0.06s None religion-and-belief-systems
# 12 [13] 0.06s None society-and-social-sciences
# 13 [14] 0.07s None technology-and-applied-sciences
# 14 [15] 0.07s None 14-climate-change
# 15 [16] 0.06s None asian-soundscape-monitoring-network
# 16 [17] 0.07s None covid-19
# 17 [18] 0.07s None transportation
# 18 [19] 0.07s None structure
# 19 [20] 0.07s None location
# 20 [21] 0.07s None health
# 21 [22] 0.06s None utilities-communication
# 22 [23] 0.07s None planning-cadastre
# 23 [24] 0.06s None boundaries
# 24 [25] 0.07s None geoscientific-information
# 25 [26] 0.07s None imagery-base-maps-earth-cover
# 26 [27] 0.07s None climatology-meteorology-atmosphere
# 27 [28] 0.07s None inland-waters
# 28 [29] 0.06s None oceans
# 29 [30] 0.04s None environment
# 30 [31] 0.06s None biota
# 31 [32] 0.05s None society
# 32 [33] 0.05s None economy
# 33 [34] 0.05s None intelligence-military
# 34 [35] 0.05s None farming
# 35 [36] 0.04s None elevation
# 36 [37] 0.05s None test2022
# 37 [38] 0.06s None uas-observation
# 38 [39] 0.05s None ntu-geog406_nstc111-6
# 39 [40] 0.04s None miaoli-com-tw
# 40 [41] 0.05s None thcts
# 41 [42] 0.05s None emergecy
# 42 [43] 0.05s None eco-check
# 43 [44] 0.05s None rdm_general
# 44 [45] 0.05s None bcs
# 45 [46] 0.06s None fgo_collection
# 46 [47] 0.07s None hualien_econet
# 47 [None] 0.05s None urbansustain

# %%
#author
author = []
for i in o_dataset[:-1]: # 最後一個沒有作者
  author.append(i['author'])
author_counts = Counter(author)

top_authors = author_counts.most_common(10)
print(top_authors)
top_authors_names = [i[0][:15] for i in top_authors]
top_authors_mentions = [i[1] for i in top_authors]


plt.bar(top_authors_names, top_authors_mentions)
plt.xlabel('Author')
plt.ylabel('Number of Mentions')
plt.xticks(rotation=70,fontsize=6)
plt.tight_layout()
plt.title('Top 10 Authors with the Most Mentions')

plt.show()
# 可以再做一個比例圓餅圖
## 得知現在的作者有誰
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 38596 (\N{CJK UNIFIED IDEOGRAPH-96C4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 24066 (\N{CJK UNIFIED IDEOGRAPH-5E02}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 25919 (\N{CJK UNIFIED IDEOGRAPH-653F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 24220 (\N{CJK UNIFIED IDEOGRAPH-5E9C}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 23616 (\N{CJK UNIFIED IDEOGRAPH-5C40}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 36914 (\N{CJK UNIFIED IDEOGRAPH-9032}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 26658 (\N{CJK UNIFIED IDEOGRAPH-6822}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 35488 (\N{CJK UNIFIED IDEOGRAPH-8AA0}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from current font.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 22830 (\N{CJK UNIFIED IDEOGRAPH-592E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 30740 (\N{CJK UNIFIED IDEOGRAPH-7814}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 31350 (\N{CJK UNIFIED IDEOGRAPH-7A76}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 38498 (\N{CJK UNIFIED IDEOGRAPH-9662}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 31038 (\N{CJK UNIFIED IDEOGRAPH-793E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 24515 (\N{CJK UNIFIED IDEOGRAPH-5FC3}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 23560 (\N{CJK UNIFIED IDEOGRAPH-5C08}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 38988 (\N{CJK UNIFIED IDEOGRAPH-984C}) missing from current font.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 22025 (\N{CJK UNIFIED IDEOGRAPH-5609}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 32681 (\N{CJK UNIFIED IDEOGRAPH-7FA9}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 32291 (\N{CJK UNIFIED IDEOGRAPH-7E23}) missing from current font.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 36898 (\N{CJK UNIFIED IDEOGRAPH-9022}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 30002 (\N{CJK UNIFIED IDEOGRAPH-7532}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 30332 (\N{CJK UNIFIED IDEOGRAPH-767C}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 23637 (\N{CJK UNIFIED IDEOGRAPH-5C55}) missing from current font.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 30928 (\N{CJK UNIFIED IDEOGRAPH-78D0}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 39015 (\N{CJK UNIFIED IDEOGRAPH-9867}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 21839 (\N{CJK UNIFIED IDEOGRAPH-554F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 32929 (\N{CJK UNIFIED IDEOGRAPH-80A1}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 20221 (\N{CJK UNIFIED IDEOGRAPH-4EFD}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 38480 (\N{CJK UNIFIED IDEOGRAPH-9650}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3497/1133245722.py:17: UserWarning: Glyph 21496 (\N{CJK UNIFIED IDEOGRAPH-53F8}) missing from current font.
#   plt.tight_layout()
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# [('高雄市政府水利局、科進栢誠工程顧問股份有限公司', 117), ('中央研究院人社中心GIS專題中心：台灣歷史文化地圖', 116), ('嘉義縣政府', 99), ('6456', 95), ('逢甲大學水利發展中心', 77), ('6458', 63), ('逢甲大學', 44), ('磐誠工程顧問股份有限公司', 44), ('samson', 37), ('Linda Chang', 37)]
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38596 (\N{CJK UNIFIED IDEOGRAPH-96C4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24066 (\N{CJK UNIFIED IDEOGRAPH-5E02}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25919 (\N{CJK UNIFIED IDEOGRAPH-653F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24220 (\N{CJK UNIFIED IDEOGRAPH-5E9C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 27700 (\N{CJK UNIFIED IDEOGRAPH-6C34}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23616 (\N{CJK UNIFIED IDEOGRAPH-5C40}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12289 (\N{IDEOGRAPHIC COMMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31185 (\N{CJK UNIFIED IDEOGRAPH-79D1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36914 (\N{CJK UNIFIED IDEOGRAPH-9032}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26658 (\N{CJK UNIFIED IDEOGRAPH-6822}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 35488 (\N{CJK UNIFIED IDEOGRAPH-8AA0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20013 (\N{CJK UNIFIED IDEOGRAPH-4E2D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22830 (\N{CJK UNIFIED IDEOGRAPH-592E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30740 (\N{CJK UNIFIED IDEOGRAPH-7814}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31350 (\N{CJK UNIFIED IDEOGRAPH-7A76}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38498 (\N{CJK UNIFIED IDEOGRAPH-9662}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31038 (\N{CJK UNIFIED IDEOGRAPH-793E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24515 (\N{CJK UNIFIED IDEOGRAPH-5FC3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23560 (\N{CJK UNIFIED IDEOGRAPH-5C08}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38988 (\N{CJK UNIFIED IDEOGRAPH-984C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22025 (\N{CJK UNIFIED IDEOGRAPH-5609}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32681 (\N{CJK UNIFIED IDEOGRAPH-7FA9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32291 (\N{CJK UNIFIED IDEOGRAPH-7E23}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36898 (\N{CJK UNIFIED IDEOGRAPH-9022}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30002 (\N{CJK UNIFIED IDEOGRAPH-7532}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22823 (\N{CJK UNIFIED IDEOGRAPH-5927}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23416 (\N{CJK UNIFIED IDEOGRAPH-5B78}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30332 (\N{CJK UNIFIED IDEOGRAPH-767C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23637 (\N{CJK UNIFIED IDEOGRAPH-5C55}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30928 (\N{CJK UNIFIED IDEOGRAPH-78D0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 39015 (\N{CJK UNIFIED IDEOGRAPH-9867}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21839 (\N{CJK UNIFIED IDEOGRAPH-554F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32929 (\N{CJK UNIFIED IDEOGRAPH-80A1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20221 (\N{CJK UNIFIED IDEOGRAPH-4EFD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26377 (\N{CJK UNIFIED IDEOGRAPH-6709}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38480 (\N{CJK UNIFIED IDEOGRAPH-9650}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/weipo/project/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21496 (\N{CJK UNIFIED IDEOGRAPH-53F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Noto Sans CJK SC
